# %%
# !git clone https://github.com/nazarb/Radogost_FileList.git
# Out:
# Cloning into 'Radogost_FileList'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 32 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 38.94 KiB | 6.49 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from Radogost_FileList.utils.download_files_from_json import download_files, FileDownloader

# %%
# Simple download
download_files(
    '/content/FileList.json',
    './Dataset',
    skip_existing=True,
    delay=0.5
)
# Out:
# ...
# Skip existing files: True
#
#   ↓ Downloading readme.txt...
#     ✓ Downloaded 10.6 KB
#   ↓ Downloading style-levee-extended.qml...
#     ✓ Downloaded 36.4 KB
#   ↓ Downloading style-river.qml...
#     ✓ Downloaded 39.5 KB
#   ↓ Downloading style.qml...
#     ✓ Downloaded 38.2 KB
#   ↓ Downloading UnderTheSands_Iraq_CFE_Network_of_levees_and_palaeo_channels.cpg...
#     ✓ Downloaded 5.0 B
#   ↓ Downloading UnderTheSands_Iraq_CFE_Network_of_levees_and_palaeo_channels.dbf...
#     ✓ Downloaded 2.7 MB
#   ↓ Downloading UnderTheSands_Iraq_CFE_Network_of_levees_and_palaeo_channels.prj...
#     ✓ Downloaded 425.0 B
#   ↓ Downloading UnderTheSands_Iraq_CFE_Network_of_levees_and_palaeo_channels.qix...
#     ✓ Downloaded 169.8 KB
#   ↓ Downloading UnderTheSands_Iraq_CFE_Network_of_levees_and_palaeo_channels.qmd...
#     ✓ Downloaded 15.6 KB
#   ↓ Downloading UnderTheSands_Iraq_CFE_Network_of_levees_and_palaeo_channels.shp...
#     ✓ Downloaded 33.7 MB
# ...
